# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    dataset = dataset.reshape(
        (-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.420487
# Minibatch accuracy: 6.2%
# Validation accuracy: 8.9%
# Minibatch loss at step 50: 1.789849
# Minibatch accuracy: 43.8%
# Validation accuracy: 44.8%
# Minibatch loss at step 100: 0.939074
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.9%
# Minibatch loss at step 150: 0.354413
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.0%
# Minibatch loss at step 200: 0.506374
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.9%
# Minibatch loss at step 250: 1.158544
# Minibatch accuracy: 50.0%
# Validation accuracy: 72.3%
# Minibatch loss at step 300: 0.578914
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 350: 0.611740
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 400: 0.687053
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 450: 1.166001
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 500: 0.381276
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 550: 0.689095
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 600: 0.554495
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 650: 0.406470
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 700: 0.307795
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 750: 0.332071
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 800: 0.576559
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 850: 0.486539
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 900: 0.507643
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 950: 0.403689
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 1000: 0.320116
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Test accuracy: 89.6%

# %%
# Problem 1

batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        conv_maxp = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')

        hidden = tf.nn.relu(conv_maxp + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        conv_maxp = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')

        hidden = tf.nn.relu(conv_maxp + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
        [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.056635
# Minibatch accuracy: 18.8%
# Validation accuracy: 9.9%
# Minibatch loss at step 50: 1.683359
# Minibatch accuracy: 37.5%
# Validation accuracy: 40.0%
# Minibatch loss at step 100: 0.921960
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.8%
# Minibatch loss at step 150: 0.383964
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.7%
# Minibatch loss at step 200: 0.597421
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 250: 0.713740
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 300: 0.634908
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 350: 0.621437
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 400: 0.536744
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 450: 1.262021
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 500: 0.345771
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 550: 0.692742
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 600: 0.464742
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 650: 0.623628
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 700: 0.238902
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 750: 0.335071
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 800: 0.486159
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 850: 0.323549
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 900: 0.588858
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 950: 0.326356
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 1000: 0.205740
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Test accuracy: 91.1%

# %%
# Problem 2

batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
learning_rate  = 0.05
decay_steps = 100000
decay_rate = 0.98

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        # convolution
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        # max pooling
        conv_maxp = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        # ReLU
        hidden = tf.nn.relu(conv_maxp + layer1_biases)
        # convolution
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        # max pooling 
        conv_maxp = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        # add a fully connected layer
        hidden = tf.nn.relu(conv_maxp + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        # dropout
        keep_prob = 0.5
        hidden_drop = tf.nn.dropout(hidden, keep_prob)
        
        # add a fully connected layer
        hidden_drop = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden_drop, layer4_weights) + layer4_biases
    
    # Model.
    def model_test(data):
        # convolution
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        # max pooling
        conv_maxp = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        # ReLU
        hidden = tf.nn.relu(conv_maxp + layer1_biases)
        # convolution
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        # max pooling 
        conv_maxp = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        # add a fully connected layer
        hidden = tf.nn.relu(conv_maxp + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        
        # add a fully connected layer
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learning_rate = tf.train.exponential_decay(0.05, global_step, decay_steps, decay_rate)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model_test(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model_test(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.128273
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.136684
# Minibatch accuracy: 12.5%
# Validation accuracy: 38.5%
# Minibatch loss at step 100: 1.059078
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.3%
# Minibatch loss at step 150: 0.559961
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.2%
# Minibatch loss at step 200: 0.694593
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 250: 0.742841
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.4%
# Minibatch loss at step 300: 0.598843
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 350: 0.534091
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 400: 0.600815
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 450: 1.139727
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 500: 0.391581
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 550: 0.768901
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 600: 0.675520
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 650: 0.473546
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 700: 0.266306
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 750: 0.443090
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 800: 0.573804
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 850: 0.440861
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 900: 0.589333
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 950: 0.573445
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 1000: 0.279339
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Test accuracy: 90.8%
