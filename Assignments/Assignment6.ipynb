# %% [markdown]
# # Includes

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %% [markdown]
# # Download file

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# # Create validation set

# %%
def read_data(filename):
    with zipfile.ZipFile(filename) as f:
        name = f.namelist()[0]
        data = tf.compat.as_str(f.read(name))
    return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# # Print sample

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# # Function to convert chars to ID and the other way around

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
    if char in string.ascii_lowercase:
        return ord(char) - first_letter + 1
    elif char == ' ':
        return 0
    else:
        print('Unexpected character: %s' % char)
        return 0
    
def id2char(dictid):
    if dictid > 0:
        return chr(dictid + first_letter - 1)
    else:
        return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# # Functin to generate batch for LSTM

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
    def __init__(self, text, batch_size, num_unrollings):
        self._text = text
        self._text_size = len(text)
        self._batch_size = batch_size
        self._num_unrollings = num_unrollings
        segment = self._text_size // batch_size
        self._cursor = [ offset * segment for offset in range(batch_size)]
        self._last_batch = self._next_batch()
  
    def _next_batch(self):
        """Generate a single batch from the current cursor position in the data."""
        batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
        for b in range(self._batch_size):
            batch[b, char2id(self._text[self._cursor[b]])] = 1.0
            self._cursor[b] = (self._cursor[b] + 1) % self._text_size
        return batch
  
    def next(self):
        """Generate the next array of batches from the data. The array consists of
        the last batch of the previous array, followed by num_unrollings new ones.
        """
        batches = [self._last_batch]
        for step in range(self._num_unrollings):
            batches.append(self._next_batch())
        self._last_batch = batches[-1]
        return batches

def characters(probabilities):
    """Turn a 1-hot encoding or a probability distribution over the possible
    characters back into its (most likely) character representation."""
    return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
    """Convert a sequence of batches back into their (most likely) string
    representation."""
    s = [''] * batches[0].shape[0]
    for b in batches:
        s = [''.join(x) for x in zip(s, characters(b))]
    return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %% [markdown]
# # More helper functions

# %%
def logprob(predictions, labels):
    """Log-probability of the true labels in a predicted batch."""
    predictions[predictions < 1e-10] = 1e-10
    return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
    """Sample one element from a distribution assumed to be an array of normalized
    probabilities.
    """
    r = random.uniform(0, 1)
    s = 0
    for i in range(len(distribution)):
        s += distribution[i]
        if s >= r:
            return i
    return len(distribution) - 1

def sample(prediction):
    """Turn a (column) prediction into 1-hot encoded samples."""
    p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
    p[0, sample_distribution(prediction[0])] = 1.0
    return p

def random_distribution():
    """Generate a random column of probabilities."""
    b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
    return b/np.sum(b, 1)[:,None]

# %% [markdown]
# # Define LST

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
    # Parameters:
    # Input gate: input, previous output, and bias.
    ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ib = tf.Variable(tf.zeros([1, num_nodes]))
    # Forget gate: input, previous output, and bias.
    fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    fb = tf.Variable(tf.zeros([1, num_nodes]))
    # Memory cell: input, state and bias.                             
    cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    cb = tf.Variable(tf.zeros([1, num_nodes]))
    # Output gate: input, previous output, and bias.
    ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ob = tf.Variable(tf.zeros([1, num_nodes]))
    # Variables saving state across unrollings.
    saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    # Classifier weights and biases.
    w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
    b = tf.Variable(tf.zeros([vocabulary_size]))

    # Definition of the cell computation.
    def lstm_cell(i, o, state):
        """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
        Note that in this formulation, we omit the various connections between the
        previous state and the gates."""
        input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
        forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
        update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
        state = forget_gate * state + input_gate * tf.tanh(update)
        output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
        return output_gate * tf.tanh(state), state

    # Input data.
    train_data = list()
    for _ in range(num_unrollings + 1):
        train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
    train_inputs = train_data[:num_unrollings]
    train_labels = train_data[1:]  # labels are inputs shifted by one time step.

    # Unrolled LSTM loop.
    outputs = list()
    output = saved_output
    state = saved_state
    for i in train_inputs:
        output, state = lstm_cell(i, output, state)
        outputs.append(output)

    # State saving across unrollings.
    with tf.control_dependencies([saved_output.assign(output), saved_state.assign(state)]):
        # Classifier.
        logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
        loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(
                labels=tf.concat(train_labels, 0), logits=logits))

    # Optimizer.
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    gradients, v = zip(*optimizer.compute_gradients(loss))
    gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
    optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

    # Predictions.
    train_prediction = tf.nn.softmax(logits)

    # Sampling and validation eval: batch 1, no unrolling.
    sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
    saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
    saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
    reset_sample_state = tf.group(
        saved_sample_output.assign(tf.zeros([1, num_nodes])),
        saved_sample_state.assign(tf.zeros([1, num_nodes])))
    sample_output, sample_state = lstm_cell(sample_input, saved_sample_output, saved_sample_state)
    with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
        sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
# Out:
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape i:  (1, 27)
# shape o:  (1, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)

# %% [markdown]
# # Run Model

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
        batches = train_batches.next()
        feed_dict = dict()
        for i in range(num_unrollings + 1):
            feed_dict[train_data[i]] = batches[i]
        _, l, predictions, lr = session.run([optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
        mean_loss += l
        if step % summary_frequency == 0:
            if step > 0:
                mean_loss = mean_loss / summary_frequency
            # The mean loss is an estimate of the loss over the last few batches.
            print('Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
            mean_loss = 0
            labels = np.concatenate(list(batches)[1:])
            print('Minibatch perplexity: %.2f' % float(np.exp(logprob(predictions, labels))))
            if step % (summary_frequency * 10) == 0:
                # Generate some samples.
                print('=' * 80)
                for _ in range(5):
                    feed = sample(random_distribution())
                    sentence = characters(feed)[0]
                    reset_sample_state.run()
                    for _ in range(79):
                        prediction = sample_prediction.eval({sample_input: feed})
                        feed = sample(prediction)
                        sentence += characters(feed)[0]
                    print(sentence)
                print('=' * 80)
            # Measure validation set perplexity.
            reset_sample_state.run()
            valid_logprob = 0
            for _ in range(valid_size):
                b = valid_batches.next()
                predictions = sample_prediction.eval({sample_input: b[0]})
                valid_logprob = valid_logprob + logprob(predictions, b[1])
            print('Validation set perplexity: %.2f' % float(np.exp(valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.299278 learning rate: 10.000000
# Minibatch perplexity: 27.09
# ================================================================================
# phhsu ewgxh xaoe  edz ijhuhpvfmr gm tsqtmeyieca du  zsmlnxpguakeiunpuff rxonttav
# e lukan homkgtfcm y pets aydghette epag zehulhonscshvercacwozafetisommaeifj dr l
# bj nterrjhghnondacp vog   mtt leml gsf wkdq o  tenlaiv qhs tsz laolza hefrzwvyu
# htupfdvsbpci jojtimaa kum gissetzlcvxsstjfd wjtitnb goeyt eby ai ewrkrlfoltjoc o
# rxxhetwek rorp suxcseyeh nosehjev vfrrgsybhp odagosrbkztrl ysnwrbmzya t d grn yo
# ================================================================================
# Validation set perplexity: 20.06
# Average loss at step 100: 2.593709 learning rate: 10.000000
# Minibatch perplexity: 10.45
# Validation set perplexity: 10.88
# Average loss at step 200: 2.245441 learning rate: 10.000000
# Minibatch perplexity: 9.41
# Validation set perplexity: 9.24
# Average loss at step 300: 2.093306 learning rate: 10.000000
# Minibatch perplexity: 7.51
# Validation set perplexity: 7.84
# Average loss at step 400: 1.992393 learning rate: 10.000000
# Minibatch perplexity: 7.64
# Validation set perplexity: 7.52
# Average loss at step 500: 1.929337 learning rate: 10.000000
# Minibatch perplexity: 6.22
# Validation set perplexity: 6.89
# Average loss at step 600: 1.906502 learning rate: 10.000000
# Minibatch perplexity: 6.10
# Validation set perplexity: 6.76
# Average loss at step 700: 1.855861 learning rate: 10.000000
# Minibatch perplexity: 5.59
# Validation set perplexity: 6.56
# Average loss at step 800: 1.819556 learning rate: 10.000000
# Minibatch perplexity: 6.15
# Validation set perplexity: 6.47
# Average loss at step 900: 1.831825 learning rate: 10.000000
# Minibatch perplexity: 7.27
# Validation set perplexity: 6.13
# Average loss at step 1000: 1.827420 learning rate: 10.000000
# Minibatch perplexity: 5.95
# ================================================================================
# d cinctions griven of the to his interencive of erigustruffured fitn eishnis sup
# le decccal intertential indifial redurat of citicistauis of chiled brovingiped c
# quin and s prict of the roping hellaty westieitions span two wildorate strinds b
# ficulity five ad ristorial breation their kkand mod cavainisting furdch theuredi
# feral gremsib for hurpiins icsial willid ripheed s blact by brectionall therelug
# ================================================================================
# Validation set perplexity: 5.95
# Average loss at step 1100: 1.775873 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 5.80
# Average loss at step 1200: 1.754943 learning rate: 10.000000
# Minibatch perplexity: 5.96
# Validation set perplexity: 5.50
# Average loss at step 1300: 1.734987 learning rate: 10.000000
# Minibatch perplexity: 5.61
# Validation set perplexity: 5.51
# Average loss at step 1400: 1.743091 learning rate: 10.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 5.48
# Average loss at step 1500: 1.735307 learning rate: 10.000000
# Minibatch perplexity: 6.41
# Validation set perplexity: 5.32
# Average loss at step 1600: 1.742334 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 5.33
# Average loss at step 1700: 1.710310 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 5.27
# Average loss at step 1800: 1.674735 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 5.20
# Average loss at step 1900: 1.646811 learning rate: 10.000000
# Minibatch perplexity: 5.94
# Validation set perplexity: 5.14
# Average loss at step 2000: 1.696089 learning rate: 10.000000
# Minibatch perplexity: 4.88
# ================================================================================
# ing matiles accumed a he from the ord jovel meart huldu slopers mines any this f
# ticual his the reversidy clathis sturning to the claster ananced sfy of intentug
# nsthem one nine nine one one six six five three two zerved when thes the suepite
#  history mavelwing in wricenakhaure the lings the elach cox the tecper on hodge
# force aperitared a dumdre two germs at from withish did tyce one six three fore
# ================================================================================
# Validation set perplexity: 5.14
# Average loss at step 2100: 1.684284 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.85
# Average loss at step 2200: 1.670664 learning rate: 10.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 5.07
# Average loss at step 2300: 1.635314 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.74
# Average loss at step 2400: 1.657318 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.76
# Average loss at step 2500: 1.676440 learning rate: 10.000000
# Minibatch perplexity: 5.82
# Validation set perplexity: 4.72
# Average loss at step 2600: 1.649397 learning rate: 10.000000
# Minibatch perplexity: 5.80
# Validation set perplexity: 4.75
# Average loss at step 2700: 1.654681 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.66
# Average loss at step 2800: 1.647508 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.59
# Average loss at step 2900: 1.651899 learning rate: 10.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 4.66
# Average loss at step 3000: 1.645671 learning rate: 10.000000
# Minibatch perplexity: 4.77
# ================================================================================
# unce algent and becate ced be passer over of son moded stan and gote paple knasp
# n one onational reforrsts sy isports at the under pace mather whereful productio
# zond becall caust he one nine one five all and may entreuted and olition s unite
# poxs topleschickars adbilited and ruck live d and the augje ind official rimelea
# chresting are a called or zeatorge then to grince and saren actority some aprric
# ================================================================================
# Validation set perplexity: 4.71
# Average loss at step 3100: 1.629094 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 4.58
# Average loss at step 3200: 1.638995 learning rate: 10.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 4.67
# Average loss at step 3300: 1.638207 learning rate: 10.000000
# Minibatch perplexity: 5.86
# Validation set perplexity: 4.54
# Average loss at step 3400: 1.664717 learning rate: 10.000000
# Minibatch perplexity: 5.99
# Validation set perplexity: 4.56
# Average loss at step 3500: 1.651752 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 4.73
# Average loss at step 3600: 1.665190 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.61
# Average loss at step 3700: 1.643664 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.55
# Average loss at step 3800: 1.640884 learning rate: 10.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.53
# Average loss at step 3900: 1.636963 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 4.52
# Average loss at step 4000: 1.644710 learning rate: 10.000000
# Minibatch perplexity: 4.54
# ================================================================================
# of most american indiall and the votters clikitical politiclal nings time in hos
# ding fam of involus the pertain g embed artayers of speliage inional with the be
# des regritical of the enty two war bat and hourdmment dooversion metantisminclus
# le objecion emperor of first sives was world attenged distage and inflient one o
# usu stinatived in a zero act do or the ycuration for geofs offirismerfifional he
# ================================================================================
# Validation set perplexity: 4.46
# Average loss at step 4100: 1.630734 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.70
# Average loss at step 4200: 1.633151 learning rate: 10.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.48
# Average loss at step 4300: 1.612868 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.43
# Average loss at step 4400: 1.607215 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.47
# Average loss at step 4500: 1.611486 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.59
# Average loss at step 4600: 1.611914 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.53
# Average loss at step 4700: 1.623838 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.40
# Average loss at step 4800: 1.628790 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.47
# Average loss at step 4900: 1.628315 learning rate: 10.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.55
# Average loss at step 5000: 1.601406 learning rate: 1.000000
# Minibatch perplexity: 5.45
# ================================================================================
# adaal condecciession of live by nosess of missist infiluce varid not b one seven
# y at that to for peomatheth distantism is they of elimuting i obinant t at the m
# urtom field civation recomer s sufmican the todestern mignary death coip fast la
# vict mosal is only olppnoted milred ba rock concervate i as counted becorions hi
# subcle implassion qoner with lit those wifpen studies desicceron amenging of the
# ================================================================================
# Validation set perplexity: 4.59
# Average loss at step 5100: 1.603007 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.40
# Average loss at step 5200: 1.587690 learning rate: 1.000000
# Minibatch perplexity: 4.48
# Validation set perplexity: 4.31
# Average loss at step 5300: 1.579222 learning rate: 1.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.31
# Average loss at step 5400: 1.575125 learning rate: 1.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.27
# Average loss at step 5500: 1.560045 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.23
# Average loss at step 5600: 1.577016 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.23
# Average loss at step 5700: 1.565108 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.22
# Average loss at step 5800: 1.581094 learning rate: 1.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.24
# Average loss at step 5900: 1.568182 learning rate: 1.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 4.20
# Average loss at step 6000: 1.543820 learning rate: 1.000000
# Minibatch perplexity: 4.97
# ================================================================================
# nation at population proferfection filijor relow companifel unto regerdmath very
# zer hot confentive itspress publics atlsy oreeced serverred ressure a gveh membe
# pp s ane historic new at ishoud large at toking in often been take to son one ro
# ules tract reuds other jelocal v of descire famik the tabber banzed where a patt
# ternation them defense they araflames faze unication which layer handing ergoses
# ================================================================================
# Validation set perplexity: 4.22
# Average loss at step 6100: 1.557759 learning rate: 1.000000
# Minibatch perplexity: 4.09
# Validation set perplexity: 4.21
# Average loss at step 6200: 1.530836 learning rate: 1.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 4.20
# Average loss at step 6300: 1.540879 learning rate: 1.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 4.20
# Average loss at step 6400: 1.539528 learning rate: 1.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.21
# Average loss at step 6500: 1.553279 learning rate: 1.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 4.23
# Average loss at step 6600: 1.589922 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.19
# Average loss at step 6700: 1.576798 learning rate: 1.000000
# Minibatch perplexity: 4.39
# Validation set perplexity: 4.23
# Average loss at step 6800: 1.599406 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.22
# Average loss at step 6900: 1.578173 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.25
# Average loss at step 7000: 1.572514 learning rate: 1.000000
# Minibatch perplexity: 4.84
# ================================================================================
# on khatfied see stield can bogid us but henran reign in brows lain is of coincul
# led of the on go dide hower of he process pass cambs often basectes the dokey el
# et this macker son seem cashomat wegenal kestur ectious of they also its of a fr
# odyss and to between rodular active herge dictions vi astator eight eight one fi
# lled dol addegancus and american to the militically fugle history see be apperou
# ================================================================================
# Validation set perplexity: 4.21

# %% [markdown]
# # Problem 1:

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
    # Parameters:
    ix_fx_cx_ox = tf.Variable(tf.truncated_normal([vocabulary_size, 4 * num_nodes], -0.1, 0.1))
    im_fm_cm_om = tf.Variable(tf.truncated_normal([num_nodes, 4 * num_nodes], -0.1, 0.1))
    ib_fb_cb_ob = tf.Variable(tf.zeros([1, 4 * num_nodes]))

    # Variables saving state across unrollings.
    saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    # Classifier weights and biases.
    w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
    b = tf.Variable(tf.zeros([vocabulary_size]))

    # Definition of the cell computation.
    def lstm_cell(i, o, state):
        """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
        Note that in this formulation, we omit the various connections between the
        previous state and the gates."""
        print('shape i: ', i.shape)
        print('shape o: ', o.shape)
        print('shape ix: ', ix.shape)
        print('shape im: ', im.shape)
        
        matmult = tf.matmul(i, ix_fx_cx_ox) + tf.matmul(o, im_fm_cm_om) + ib_fb_cb_ob
        print('shape matmult: ', matmult.shape)
        t = matmult[:,0:num_nodes]
        print('shape t: ', t.shape)
        input_gate = tf.sigmoid(matmult[:,0:num_nodes])
        forget_gate = tf.sigmoid(matmult[:,num_nodes:2*num_nodes-1])
        update = matmult[:,2*num_nodes:3*num_nodes-1]
        state = forget_gate * state + input_gate * tf.tanh(update)
        output_gate = tf.sigmoid(matmult[:,3*num_nodes:4*num_nodes-1])
        return output_gate * tf.tanh(state), state
    
#     # Problem 1: Solution
#     def lstm_cell(i,o,state):
        

    # Input data.
    train_data = list()
    for _ in range(num_unrollings + 1):
        train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
    train_inputs = train_data[:num_unrollings]
    train_labels = train_data[1:]  # labels are inputs shifted by one time step.

    # Unrolled LSTM loop.
    outputs = list()
    output = saved_output
    state = saved_state
    for i in train_inputs:
        output, state = lstm_cell(i, output, state)
        outputs.append(output)

    # State saving across unrollings.
    with tf.control_dependencies([saved_output.assign(output), saved_state.assign(state)]):
        # Classifier.
        logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
        loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(
                labels=tf.concat(train_labels, 0), logits=logits))

    # Optimizer.
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    gradients, v = zip(*optimizer.compute_gradients(loss))
    gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
    optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

    # Predictions.
    train_prediction = tf.nn.softmax(logits)

    # Sampling and validation eval: batch 1, no unrolling.
    sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
    saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
    saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
    reset_sample_state = tf.group(
        saved_sample_output.assign(tf.zeros([1, num_nodes])),
        saved_sample_state.assign(tf.zeros([1, num_nodes])))
    sample_output, sample_state = lstm_cell(sample_input, saved_sample_output, saved_sample_state)
    with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
        sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
# Out:
# shape i:  (64, 27)
# shape o:  (64, 64)
# shape ix:  (27, 64)
# shape im:  (64, 64)
# shape matmult:  (64, 256)
# shape t:  (64, 64)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     670           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 671           input_tensors_as_shapes, status)
#     672   except errors.InvalidArgumentError as err:
#
# /home.net/je16dek/anaconda3/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Dimensions must be equal, but are 63 and 64 for 'mul' (op: 'Mul') with input shapes: [64,63], [64,64].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-31fff10bf71e> in <module>()
#      54     state = saved_state
#      55     for i in train_inputs:
# ---> 56         output, state = lstm_cell(i, output, state)
#      57         outputs.append(output)
#      58
#
# <ipython-input-21-31fff10bf71e> in lstm_cell(i, o, state)
#      34         forget_gate = tf.sigmoid(matmult[:,num_nodes:2*num_nodes-1])
#      35         update = matmult[:,2*num_nodes:3*num_nodes-1]
# ---> 36         state = forget_gate * state + input_gate * tf.tanh(update)
#      37         output_gate = tf.sigmoid(matmult[:,3*num_nodes:4*num_nodes-1])
#      38         return output_gate * tf.tanh(state), state
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#     819       if not isinstance(y, sparse_tensor.SparseTensor):
#     820         y = ops.convert_to_tensor(y, dtype=x.dtype.base_dtype, name="y")
# --> 821       return func(x, y, name=name)
#     822
#     823   def binary_op_wrapper_sparse(sp_x, y):
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in _mul_dispatch(x, y, name)
#    1042   is_tensor_y = isinstance(y, ops.Tensor)
#    1043   if is_tensor_y:
# -> 1044     return gen_math_ops._mul(x, y, name=name)
#    1045   else:
#    1046     assert isinstance(y, sparse_tensor.SparseTensor)  # Case: Dense * Sparse.
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _mul(x, y, name)
#    1432     A `Tensor`. Has the same type as `x`.
#    1433   """
# -> 1434   result = _op_def_lib.apply_op("Mul", x=x, y=y, name=name)
#    1435   return result
#    1436
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     766         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     767                          input_types=input_types, attrs=attr_protos,
# --> 768                          op_def=op_def)
#     769         if output_structure:
#     770           outputs = op.outputs
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2336                     original_op=self._default_original_op, op_def=op_def)
#    2337     if compute_shapes:
# -> 2338       set_shapes_for_outputs(ret)
#    2339     self._add_op(ret)
#    2340     self._record_op_seen_by_control_dependencies(ret)
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in set_shapes_for_outputs(op)
#    1717       shape_func = _call_cpp_shape_fn_and_require_op
#    1718
# -> 1719   shapes = shape_func(op)
#    1720   if shapes is None:
#    1721     raise RuntimeError(
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in call_with_requiring(op)
#    1667
#    1668   def call_with_requiring(op):
# -> 1669     return call_cpp_shape_fn(op, require_shape_fn=True)
#    1670
#    1671   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in call_cpp_shape_fn(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     608     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     609                                   input_tensors_as_shapes_needed,
# --> 610                                   debug_python_shape_fn, require_shape_fn)
#     611     if not isinstance(res, dict):
#     612       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# /home.net/je16dek/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     674       missing_shape_fn = True
#     675     else:
# --> 676       raise ValueError(err.message)
#     677
#     678   if missing_shape_fn:
#
# ValueError: Dimensions must be equal, but are 63 and 64 for 'mul' (op: 'Mul') with input shapes: [64,63], [64,64].
